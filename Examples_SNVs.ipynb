# %%
# --- Imports ---
import pandas as pd

# %%
# Load K562 E-Gs
df1 = pd.read_csv('K562/K562.network.tsv', sep = '\t')

print(df1.shape)
df1.head(n = 5)
# Out:
# (78062, 9)
#   chrom  chromStart  chromEnd                         name       class  \
# 0  chr1        9863     10662   intergenic|chr1:9863-10662  intergenic
# 1  chr1        9863     10662   intergenic|chr1:9863-10662  intergenic
# 2  chr1        9863     10662   intergenic|chr1:9863-10662  intergenic
# 3  chr1       29099     29599  intergenic|chr1:29099-29599  intergenic
# 4  chr1       29099     29599  intergenic|chr1:29099-29599  intergenic
#
#   targetGene  targetEnsemblID cellType    MPRabc
# 0      OR4F5  ENSG00000186092     K562  0.352643
# 1    FAM138F  ENSG00000282591     K562  0.455790
# 2    FAM138A  ENSG00000237613     K562  0.455790
# 3      OR4F5  ENSG00000186092     K562  0.312436
# 4    FAM138F  ENSG00000282591     K562  0.766666

# %%
# Load K562 TFs
df2 = pd.read_csv('K562/K562.FIMO.VERIFIED.tsv', sep = '\t')

print(df2.shape)
df2.head(n = 5)
# Out:
# (1472664, 10)
#   chrom  chromStart  chromEnd                        name     score strand  \
# 0  chr1       10104     10122  intergenic|chr1:9863-10662  10.79820      +
# 1  chr1       10286     10304  intergenic|chr1:9863-10662   9.94495      +
# 2  chr1       10287     10305  intergenic|chr1:9863-10662  14.08260      +
# 3  chr1       10288     10306  intergenic|chr1:9863-10662  15.75230      +
# 4  chr1       10292     10310  intergenic|chr1:9863-10662   9.94495      +
#
#     motifID motifAltID        pValue      matchedSequence
# 0  MA0073.2      RREB1  6.810000e-06  ACCCAACCCTAACCCTAAC
# 1  MA0073.2      RREB1  9.290000e-06  ACCCCAACCCCAACCCCAA
# 2  MA0073.2      RREB1  1.840000e-06  CCCCAACCCCAACCCCAAC
# 3  MA0073.2      RREB1  9.130000e-07  CCCAACCCCAACCCCAACC
# 4  MA0073.2      RREB1  9.290000e-06  ACCCCAACCCCAACCCCAA

# %%
# Load K562 SNVs
df3 = pd.read_csv('variants/K562.variants.hg38.bed', sep = '\t', names = ['chrom', 'chromStart', 'chromEnd', 'name'])

print(df3.shape)
df3.head(n = 5)
# Out:
# (6803, 4)
#   chrom  chromStart  chromEnd        name
# 0  chr1     2188393   2188394   rs2460002
# 1  chr1     2189185   2189186   rs2503700
# 2  chr1     2214725   2214726  rs78265569
# 3  chr1     2216434   2216435  rs10910028
# 4  chr1     2231567   2231568  rs10910031

# %%
# Filter FIMO
motifs = df2[df2['motifAltID'] == 'GATA1::TAL1'].copy()
motifs = motifs.rename(columns = {'name': 'region_name', 'chromStart': 'motifStart', 'chromEnd': 'motifEnd'})

# %%
# Format variants
variants = df3.rename(columns={'name': 'rsID', 'chromStart': 'varStart', 'chromEnd': 'varEnd'})

# %%
# Calculate overlaps
overlaps = (motifs.merge(variants, on = 'chrom', how = 'inner'))
overlaps = overlaps[(overlaps['varStart'] < overlaps['motifEnd']) & (overlaps['varEnd'] > overlaps['motifStart'])].copy()

print(f'Motf-variant overlaps: {overlaps.shape[0]}')
# Out:
# Motf-variant overlaps: 2

# %%
# Example regions
hit_regions = overlaps['region_name'].unique()
print(f'Example regionst: {len(hit_regions)}')
# Out:
# Example regionst: 2

# %%
# Results
df_final = df1[df1['name'].isin(hit_regions)].copy()
df_final
# Out:
#        chrom  chromStart  chromEnd                                name  \
# 24836  chr15    31364317  31364817       genic|chr15:31364317-31364817
# 24837  chr15    31364317  31364817       genic|chr15:31364317-31364817
# 48819  chr21    34995969  34996728  intergenic|chr21:34995969-34996728
#
#             class targetGene  targetEnsemblID cellType    MPRabc
# 24836       genic      KLF13  ENSG00000169926     K562  0.576051
# 24837       genic     CHRNA7  ENSG00000175344     K562  0.693924
# 48819  intergenic      RUNX1  ENSG00000159216     K562  0.352798
